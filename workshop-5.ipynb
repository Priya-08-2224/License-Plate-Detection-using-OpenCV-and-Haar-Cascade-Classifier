# %% [markdown]
# ## Workshop 5
# ## Name : Rithika L
# ## Reg no: 212224230231

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("img.png")      # Read image
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)
plt.title("Original Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(1198.5), np.float64(665.5), np.float64(-0.5))

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.imshow(gray, cmap="gray")
plt.title("Grayscale Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(1198.5), np.float64(665.5), np.float64(-0.5))

# %%
cascade_path = cv2.data.haarcascades + "haarcascade_russian_plate_number.xml"
plate_cascade = cv2.CascadeClassifier(cascade_path)

plates = plate_cascade.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=5,
    minSize=(30,30)
)

for (x, y, w, h) in plates:
    cv2.rectangle(img_rgb, (x, y), (x+w, y+h), (0,255,0), 2)

plt.figure(figsize=(8,6))
plt.imshow(img_rgb)
plt.title("Detected License Plate")
plt.axis("off")
plt.show()

# %%
for (x, y, w, h) in plates:
    
    plate_region = img[y:y+h, x:x+w]

    blurred_plate = cv2.GaussianBlur(plate_region, (51,51), 30)
    
    img[y:y+h, x:x+w] = blurred_plate

img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(8,6))
plt.imshow(img_rgb)
plt.title("Blurred License Plate")
plt.axis("off")
plt.show()

# %%
for (x, y, w, h) in plates:
    
    plate_region = img[y:y+h, x:x+w]

    blurred_plate = cv2.GaussianBlur(plate_region, (51,51), 30)
    
    img[y:y+h, x:x+w] = blurred_plate

img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(8,6))
plt.imshow(img_rgb)
plt.title("Blurred License Plate")
plt.axis("off")
plt.show()
